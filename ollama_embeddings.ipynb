# %%
from langchain_community.embeddings import OllamaEmbeddings

# %%
embeddings = (
    OllamaEmbeddings(model = "gemma:2b")
    )
# Out:
# C:\Users\ashutoshawasthi\AppData\Local\Temp\ipykernel_2684\106965500.py:2: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaEmbeddings``.
#   OllamaEmbeddings(model = "gemma:2b")

# %%
r1 = embeddings.embed_documents([
    "Alpha is the first Character of the greek abc"
    "Beta is the second charcter of the greek abc"
])

# %%
len(r1[0])
# Out:
# 2048
